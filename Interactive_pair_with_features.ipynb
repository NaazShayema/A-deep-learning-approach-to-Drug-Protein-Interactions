# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Creating "Interactive.csv" :-**
#
# 'uniprot links 3.csv' contains the interaction between drugs and proteins
#
# uniprot links 3 ----> unique drug ids (we remove duplicates) and created a new csv file named 'unique_Drug_IDs.csv' and it has 1 column named 'DrugBank ID'
#
#
# uniprot links 3 ----> unique protein ids (we remove duplicates) and created a new csv file named 'Unique_prot_Ids.csv' and it has 1 column named 'UniProt ID'
#
# Then we merged these two csv files.

# %%
import pandas as pd
pd.read_csv('/content/drive/MyDrive/Datasets/D_P_Interaction/Interactive.csv')
# Out:
#       DrugBank ID UniProt ID
# 0         DB00001     P00734
# 1         DB00002     P00533
# 2         DB00002     O75015
# 3         DB00002     P02745
# 4         DB00002     P02746
# ...           ...        ...
# 22409     DB17851     Q04609
# 22410     DB17992     E0W492
# 22411     DB18236     Q07912
# 22412     DB18704     Q99062
# 22413     DB18716     P37321
#
# [22414 rows x 2 columns]

# %% [markdown]
# **Creating 'Interactive_pair_with_features.csv'**
#
# which contains drug & protein pair which interact with each other and their corresponding features

# %%
import pandas as pd

# Read Interactive.csv file
interactive_df = pd.read_csv('/content/drive/MyDrive/Datasets/D_P_Interaction/Interactive.csv')

# Initialize an empty DataFrame to store the merged data
merged_df = interactive_df.copy()

# List of paths to other CSV files
#other_uniprot_files = ['/content/drive/MyDrive/Datasets/Protein_Features/AAC_updated_final.csv','/content/drive/MyDrive/Datasets/Protein_Features/DC_updated_final.csv','/content/drive/MyDrive/Datasets/Protein_Features/CTDC_updated_fianl.csv','/content/drive/MyDrive/Datasets/Protein_Features/CTDD_updated_final.csv','/content/drive/MyDrive/Datasets/Protein_Features/CTDT_updated_final.csv']
other_drugbank_files = ['/content/drive/MyDrive/Datasets/Drug_Features/DrugAminoAcidCount_final.csv','/content/drive/MyDrive/Datasets/Drug_Features/DrugAtomCount_final.csv','/content/drive/MyDrive/Datasets/Drug_Features/DrugAutocorrelationMass_final.csv','/content/drive/MyDrive/Datasets/Drug_Features/DrugCarbonTypes_final.csv','/content/drive/MyDrive/Datasets/Drug_Features/DrugKierHallSmarts_final.csv']
other_uniprot_files = ['/content/drive/MyDrive/Datasets/Protein_Features/AAC_updated_final.csv','/content/drive/MyDrive/Datasets/Protein_Features/DC_updated_final.csv','/content/drive/MyDrive/Datasets/Protein_Features/CTDC_updated_fianl.csv','/content/drive/MyDrive/Datasets/Protein_Features/CTDD_updated_final.csv','/content/drive/MyDrive/Datasets/Protein_Features/CTDT_updated_final.csv']

# # Merge data from files with 'UniProt ID' column
# for file in other_uniprot_files:
#     temp_df = pd.read_csv(file)
#     merged_df = pd.merge(merged_df, temp_df, on='UniProt ID', how='inner')

# Merge data from files with 'Drugbank ID' column
for file in other_drugbank_files:
    temp_df = pd.read_csv(file)
    merged_df = pd.merge(merged_df, temp_df, on='DrugBank ID', how='inner')

# Merge data from files with 'UniProt ID' column
for file in other_uniprot_files:
    temp_df = pd.read_csv(file)
    merged_df = pd.merge(merged_df, temp_df, on='UniProt ID', how='inner')


# Write the merged data to a new CSV file
merged_df.to_csv('Interactive_pair_with_features.csv', index=False)

# %%
import pandas as pd

# Read the CSV files
smiles_output_2 = pd.read_csv('/content/drive/MyDrive/Datasets/smiles_output_2.csv')
Interactive_pair_with_features = pd.read_csv('/content/Interactive_pair_with_features.csv')

# Get the 'UniProt ID' columns from both DataFrames
smiles_drugbank_ids = set(merged_df['DrugBank ID'])
Interactive_drugbank_ids = set(interactive_df['DrugBank ID'])

# Check if all values in 'merged_uniprot_ids' are present in 'interactive_uniprot_ids'
if Interactive_drugbank_ids.issubset(smiles_drugbank_ids):
    print("All values in 'DrugBank ID' column from Interactive_pair_with_features.csv are present in 'DrugBank ID' column from smiles_output_2.csv.")
else:
    print("Not all values in 'DrugBank ID' column from Interactive_pair_with_features.csv are present in 'DrugBank ID' column from smiles_output_2.csv.")
# Out:
# Not all values in 'DrugBank ID' column from Interactive_pair_with_features.csv are present in 'DrugBank ID' column from smiles_output_2.csv.
